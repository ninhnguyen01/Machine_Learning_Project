# %% [markdown]
# # Image Recognition Project (Pop Culture - Oppenheimer x Barbie)
# # by Ninh Nguyen

# %% [markdown]
# ### Note: The images don't belong to me. All credit goes to the creator of the images.

# %%
import PIL.Image
import PIL.ImageDraw

import face_recognition

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Read Image
img = mpimg.imread('Oppenheimer x Barbie.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('Oppenheimer x Barbie.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="pink",width=5)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 167, Left: 442, Bottom: 322, Right: 597

# %%
# Read Image
img = mpimg.imread('Result.png')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('Oppenheimer x Barbie 1.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('Oppenheimer x Barbie 1.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="pink",width=5)

# Display the image on screen
pil_image.show()
# Out:
# I found 2 face(s) in this photograph.
# A face is located at pixel location Top: 718, Left: 408, Bottom: 872, Right: 562
# A face is located at pixel location Top: 167, Left: 683, Bottom: 322, Right: 838

# %%
# Read Image
img = mpimg.imread('Result1.png')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('Oppenheimer x Barbie 2.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('Oppenheimer x Barbie 2.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="pink",width=5)

# Display the image on screen
pil_image.show()
# Out:
# I found 1 face(s) in this photograph.
# A face is located at pixel location Top: 810, Left: 217, Bottom: 846, Right: 253

# %%
# Read Image
img = mpimg.imread('Result2.png')
 
# Output Image
plt.imshow(img)

# %%
# Read Image
img = mpimg.imread('Oppenheimer x Barbie 3.png')
 
# Output Image
plt.imshow(img)

# %%
# Load the jpg file into a numpy array
image = face_recognition.load_image_file('Oppenheimer x Barbie 3.png')

# Find all the faces in the image
face_locations = face_recognition.face_locations(image)

number_of_faces = len(face_locations)
print("I found {} face(s) in this photograph.".format(number_of_faces))

# Load the image into a Python Image Library object so that we can draw on top of it and display it
pil_image = PIL.Image.fromarray(image)

for face_location in face_locations:

    # Print the location of each face in this image. Each face is a list of co-ordinates in (top, right, bottom, left) order.
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # Let's draw a box around the face
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline="pink",width=5)

# Display the image on screen
pil_image.show()
# Out:
# I found 3 face(s) in this photograph.
# A face is located at pixel location Top: 133, Left: 408, Bottom: 288, Right: 562
# A face is located at pixel location Top: 286, Left: 7, Bottom: 329, Right: 50
# A face is located at pixel location Top: 303, Left: 907, Bottom: 355, Right: 959

# %%
# Read Image
img = mpimg.imread('Result3.png')
 
# Output Image
plt.imshow(img)
